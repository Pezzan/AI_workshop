# %% [markdown]
# <a href="https://colab.research.google.com/github/Pezzan/AI_workshop/blob/main/01_LLM_call.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.abs(-1)
# Out:
# np.int64(1)
